# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import SpectralClustering, KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
import plotly.express as px
# %matplotlib inline
from sklearn.manifold import TSNE
from sklearn.cluster import SpectralClustering, KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from tqdm import tqdm_notebook
from utils import plotting_object, plotting_kde_num, plot_clustering, plotting_num, \
plot_size, silhouette_plot

from utils import *

from sklearn.metrics import (
    calinski_harabasz_score,
    silhouette_samples,
    silhouette_score
)
r_seed = np.random.seed(758)

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %%
df = pd.read_excel(r'Full_data.xlsx', index_col=0,  header= 4 )

# %%
df.head(3)
# Out:
#                                Численность населения, чел  \
# Российская Федеpация                          146171015.0
# Центральный федеральный округ                         NaN
# Белгородская область                            1541259.0
#
#                                Средняя зарплата 2019/2017, %  \
# Российская Федеpация                                111.6465
# Центральный федеральный округ                            NaN
# Белгородская область                                110.0040
#
#                                Средняя зарплата 2020/2017, %  \
# Российская Федеpация                                   116.6
# Центральный федеральный округ                            NaN
# Белгородская область                                   116.1
#
#                                Средняя зарплата 2020/2019, %  \
# Российская Федеpация                                   102.5
# Центральный федеральный округ                            NaN
# Белгородская область                                   104.5
#
#                                Отклонение от увеличения средней зарплаты округу, %  \
# Российская Федеpация                                                         NaN
# Центральный федеральный округ                                                NaN
# Белгородская область                                                    2.705556
#
#                                Темп роста денежного дохода населения в 2020  \
# Российская Федеpация                                                    NaN
# Центральный федеральный округ                                           NaN
# Белгородская область                                                   98.4
#
#                                Объем жилищного строительства, тыс м2  \
# Российская Федеpация                                         82.1845
# Центральный федеральный округ                                    NaN
# Белгородская область                                          1.1486
#
#                                Ввод жилья  МКД, тыс м2  \
# Российская Федеpация                           42.3827
# Центральный федеральный округ                      NaN
# Белгородская область                            0.2136
#
#                                Ввод жилья, построенного населением, тыс м2  \
# Российская Федеpация                                               39.8018
# Центральный федеральный округ                                          NaN
# Белгородская область                                                0.9350
#
#                                Объем жилищного строительства,  м2/чел  ...  \
# Российская Федеpация                                         0.562249  ...
# Центральный федеральный округ                                     NaN  ...
# Белгородская область                                         0.745235  ...
#
#                                Кол-во высокопр-ных мест труда 2020, тыс  \
# Российская Федеpация                                          16938.284
# Центральный федеральный округ                                       NaN
# Белгородская область                                            217.078
#
#                                Относительное кол-во высокопр-ных мест труда 2020, 1/чел   \
# Российская Федеpация                                                         NaN
# Центральный федеральный округ                                                NaN
# Белгородская область                                                    0.140845
#
#                                Рост высокопр-ных мест труда 2020/2019, %  \
# Российская Федеpация                                          104.267663
# Центральный федеральный округ                                        NaN
# Белгородская область                                          109.707384
#
#                                Отклонение от среднего по округу роста высокопр-ных мест труда, %  \
# Российская Федеpация                                                         NaN
# Центральный федеральный округ                                                NaN
# Белгородская область                                                    4.395232
#
#                                Уровень бедности 2018, %  \
# Российская Федеpация                               12.6
# Центральный федеральный округ                       NaN
# Белгородская область                                7.5
#
#                                Уровень бедности 2019, %  \
# Российская Федеpация                               12.3
# Центральный федеральный округ                       NaN
# Белгородская область                                7.8
#
#                                Уровень бедности 2020, %  \
# Российская Федеpация                               12.1
# Центральный федеральный округ                       NaN
# Белгородская область                                7.2
#
#                                Уровень бедности 2020/2018, %  \
# Российская Федеpация                               96.031746
# Центральный федеральный округ                            NaN
# Белгородская область                               96.000000
#
#                                Уровень бедности 2020/2019, %  \
# Российская Федеpация                               98.373984
# Центральный федеральный округ                            NaN
# Белгородская область                               92.307692
#
#                                Отклонение изменения уровня бедности, 2020/2019, %
# Российская Федеpация                                                         NaN
# Центральный федеральный округ                                                NaN
# Белгородская область                                                   -5.039706
#
# [3 rows x 38 columns]

# %%
df.index
# Out:
# Index(['Российская Федеpация', 'Центральный федеральный округ',
#        'Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'Липецкая область',
#        'Московская область', 'Орловская область', 'Рязанская область',
#        'Смоленская область', 'Тамбовская область', 'Тверская область',
#        'Тульская область', 'Ярославская область', 'г. Москва',
#        'Северо-Западный федеральный округ', 'Республика Карелия',
#        'Республика Коми', 'Ненецкий автономный округ',
#        'Архангельская область без Ненецкого автономного округа',
#        'Вологодская область', 'Калининградская область',
#        'Ленинградская область', 'Мурманская область', 'Новгородская область',
#        'Псковская область', 'г.Санкт-Петербург ', 'Южный федеральный округ',
#        'Республика Адыгея', 'Республика Калмыкия', 'Республика Крым',
#        'Краснодарский край', 'Астраханская область', 'Волгоградская область',
#        'Ростовская область', 'г. Севастополь',
#        'Северо-Кавказский федеральный округ', 'Республика Дагестан',
#        'Республика Ингушетия', 'Кабардино-Балкарская Республика',
#        'Карачаево-Черкесская Республика', 'Республика Северная Осетия-Алания',
#        'Чеченская Республика', 'Ставропольский край',
#        'Приволжский федеральный округ', 'Республика Башкортостан',
#        'Республика Марий Эл ', 'Республика Мордовия', 'Республика Татарстан',
#        'Удмуртская Республика', 'Чувашская Республика', 'Пермский край',
#        'Кировская область', 'Нижегородская область', 'Оренбургская область',
#        'Пензенская область', 'Самарская область', 'Саратовская область',
#        'Ульяновская область', 'Уральский федеральный округ',
#        'Курганская область', 'Свердловская область', 'Тюменская область ',
#        'Ханты-Мансийский автономный округ-Югра',
#        'Ямало-Ненецкий автономный округ',
#        'Тюменская область без автономных округов', 'Челябинская область',
#        'Сибирский федеральный округ', 'Республика Алтай', 'Республика Тыва',
#        'Республика Хакасия', 'Алтайский край', 'Красноярский край ',
#        'Иркутская область', 'Кемеровская область', 'Новосибирская область',
#        'Омская область', 'Томская область',
#        'Дальневосточный федеральный округ', 'Республика Бурятия',
#        'Республика Саха (Якутия)', 'Забайкальский край', 'Камчатский край',
#        'Приморский край', 'Хабаровский край', 'Амурская область',
#        'Магаданская область', 'Сахалинская область',
#        'Еврейская автономная область', 'Чукотский автономный округ'],
#       dtype='object')

# %%
mask = [*map(lambda x: x[-4:] not in ['круг','ация'] , df.index)]

# %%
df = df[mask]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, Белгородская область to Еврейская автономная область
# Data columns (total 38 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Численность населения, чел                                          83 non-null     float64
#  1   Средняя зарплата 2019/2017, %                                       83 non-null     float64
#  2   Средняя зарплата 2020/2017, %                                       83 non-null     float64
#  3   Средняя зарплата 2020/2019, %                                       83 non-null     float64
#  4   Отклонение от увеличения средней зарплаты округу, %                 83 non-null     float64
#  5   Темп роста денежного дохода населения в 2020                        83 non-null     float64
#  6   Объем жилищного строительства, тыс м2                               83 non-null     float64
#  7   Ввод жилья  МКД, тыс м2                                             83 non-null     float64
#  8   Ввод жилья, построенного населением, тыс м2                         83 non-null     float64
#  9   Объем жилищного строительства,  м2/чел                              83 non-null     float64
#  10  Отклонение от среднего по округу объема жилищного строительства, %  83 non-null     float64
#  11  ОПЖ, 2018 г., лет                                                   83 non-null     float64
#  12  ОПЖ, 2019 г., лет                                                   83 non-null     float64
#  13  ОПЖ, 2020 г., лет                                                   83 non-null     float64
#  14  Изменение ОПЖ 2020/2019                                             83 non-null     float64
#  15  Отклонение от среднего по округу изменения ОПЖ, лет                 83 non-null     float64
#  16  Прирост населения, 2018, на тыс                                     83 non-null     float64
#  17  Прирост населения, 2019, на тыс                                     83 non-null     float64
#  18  Прирост населения, 2020, на тыс                                     83 non-null     float64
#  19  Изменение прироста населения, 2020/2019, %                          83 non-null     float64
#  20  Отклонение от среднего по округу изменения ОПЖ, лет.1               83 non-null     float64
#  21  Индекс пр-сти труда 2018/2017 , %                                   83 non-null     float64
#  22  Индекс пр-сти труда 2019/2018, %                                    83 non-null     float64
#  23  Индекс пр-сти труда 2020 / 2019, %                                  83 non-null     float64
#  24  Индекс пр-сти труда 2020 / 2017, %                                  83 non-null     float64
#  25  Увеличение темпа прироста пр-сти труда  (2020/2019), %              83 non-null     float64
#  26  Отклонение от среднего по округу изменения темпа пр-та пр-сти, %    83 non-null     float64
#  27  Кол-во высокопр-ных мест труда 2019, тыс                            83 non-null     float64
#  28  Кол-во высокопр-ных мест труда 2020, тыс                            83 non-null     float64
#  29  Относительное кол-во высокопр-ных мест труда 2020, 1/чел            73 non-null     float64
#  30  Рост высокопр-ных мест труда 2020/2019, %                           83 non-null     float64
#  31  Отклонение от среднего по округу роста высокопр-ных мест труда, %   83 non-null     float64
#  32  Уровень бедности 2018, %                                            83 non-null     float64
#  33  Уровень бедности 2019, %                                            83 non-null     float64
#  34  Уровень бедности 2020, %                                            83 non-null     float64
#  35  Уровень бедности 2020/2018, %                                       83 non-null     float64
#  36  Уровень бедности 2020/2019, %                                       83 non-null     float64
#  37  Отклонение изменения уровня бедности, 2020/2019, %                  83 non-null     float64
# dtypes: float64(38)
# memory usage: 25.3+ KB

# %%
df.describe()
# Out:
#        Численность населения, чел  Средняя зарплата 2019/2017, %  \
# count                8.300000e+01                      83.000000
# mean                 1.798893e+06                     111.220566
# std                  1.821795e+06                       3.277014
# min                  1.390340e+05                     103.688000
# 25%                  7.804055e+05                     108.896100
# 50%                  1.207875e+06                     110.656600
# 75%                  2.340314e+06                     113.064400
# max                  1.265505e+07                     119.880000
#
#        Средняя зарплата 2020/2017, %  Средняя зарплата 2020/2019, %  \
# count                      83.000000                      83.000000
# mean                      115.137349                     102.413253
# std                         4.453629                       1.938366
# min                       104.400000                      97.700000
# 25%                       112.850000                     101.050000
# 50%                       114.400000                     102.400000
# 75%                       117.900000                     103.800000
# max                       127.800000                     107.500000
#
#        Отклонение от увеличения средней зарплаты округу, %  \
# count                                          83.000000
# mean                                           -0.136348
# std                                             1.774791
# min                                            -5.163636
# 25%                                            -1.132937
# 50%                                            -0.163636
# 75%                                             1.014286
# max                                             5.600000
#
#        Темп роста денежного дохода населения в 2020  \
# count                                     83.000000
# mean                                      97.842169
# std                                        2.087776
# min                                       91.900000
# 25%                                       96.600000
# 50%                                       97.900000
# 75%                                       99.300000
# max                                      104.700000
#
#        Объем жилищного строительства, тыс м2  Ввод жилья  МКД, тыс м2  \
# count                              83.000000                83.000000
# mean                                1.020669                 0.529271
# std                                 1.319132                 0.834248
# min                                 0.009000                 0.000000
# 25%                                 0.290900                 0.118550
# 50%                                 0.650400                 0.251500
# 75%                                 1.161400                 0.508200
# max                                 9.040300                 4.554400
#
#        Ввод жилья, построенного населением, тыс м2  \
# count                                    83.000000
# mean                                      0.491398
# std                                       0.601787
# min                                       0.004600
# 25%                                       0.157350
# 50%                                       0.330000
# 75%                                       0.608950
# max                                       4.485800
#
#        Объем жилищного строительства,  м2/чел  ...  \
# count                               83.000000  ...
# mean                                 0.515169  ...
# std                                  0.258140  ...
# min                                  0.048577  ...
# 25%                                  0.348034  ...
# 50%                                  0.470988  ...
# 75%                                  0.604369  ...
# max                                  1.408562  ...
#
#        Кол-во высокопр-ных мест труда 2020, тыс  \
# count                                 83.000000
# mean                                 210.708157
# std                                  296.445540
# min                                    5.364000
# 25%                                   66.039000
# 50%                                  130.683000
# 75%                                  228.374000
# max                                 2224.802000
#
#        Относительное кол-во высокопр-ных мест труда 2020, 1/чел   \
# count                                          73.000000
# mean                                            0.100927
# std                                             0.041790
# min                                             0.008733
# 25%                                             0.082302
# 50%                                             0.098959
# 75%                                             0.125977
# max                                             0.231619
#
#        Рост высокопр-ных мест труда 2020/2019, %  \
# count                                  83.000000
# mean                                  104.335833
# std                                     6.260109
# min                                    86.329505
# 25%                                   100.366586
# 50%                                   104.661223
# 75%                                   107.521053
# max                                   125.342219
#
#        Отклонение от среднего по округу роста высокопр-ных мест труда, %  \
# count                                          83.000000
# mean                                            0.017304
# std                                             5.765536
# min                                           -11.382667
# 25%                                            -3.540549
# 50%                                            -0.455192
# 75%                                             3.075273
# max                                            19.132092
#
#        Уровень бедности 2018, %  Уровень бедности 2019, %  \
# count                 83.000000                 83.000000
# mean                  14.474699                 14.465060
# std                    5.026196                  5.041231
# min                    6.600000                  6.500000
# 25%                   11.400000                 11.650000
# 50%                   13.800000                 13.800000
# 75%                   16.700000                 16.250000
# max                   34.400000                 34.100000
#
#        Уровень бедности 2020, %  Уровень бедности 2020/2018, %  \
# count                 83.000000                      83.000000
# mean                  14.175904                      97.687947
# std                    5.053147                       3.694619
# min                    5.900000                      89.261745
# 25%                   11.200000                      95.129073
# 50%                   13.600000                      98.039216
# 75%                   16.050000                     100.000000
# max                   34.100000                     110.204082
#
#        Уровень бедности 2020/2019, %  \
# count                      83.000000
# mean                       97.735771
# std                         2.294506
# min                        90.769231
# 25%                        96.171460
# 50%                        97.777778
# 75%                       100.000000
# max                       101.574803
#
#        Отклонение изменения уровня бедности, 2020/2019, %
# count                                          83.000000
# mean                                            0.105704
# std                                             2.149652
# min                                            -7.713265
# 25%                                            -1.068668
# 50%                                             0.097242
# 75%                                             1.517505
# max                                             4.552336
#
# [8 rows x 38 columns]

# %%
for idx, col in enumerate(df.columns):
    print(f'{idx}-{col}')
# Out:
# 0-Численность населения, чел
# 1-Средняя зарплата 2019/2017, %
# 2-Средняя зарплата 2020/2017, %
# 3-Средняя зарплата 2020/2019, %
# 4-Отклонение от увеличения средней зарплаты округу, %
# 5-Темп роста денежного дохода населения в 2020
# 6-Объем жилищного строительства, тыс м2
# 7-Ввод жилья  МКД, тыс м2
# 8-Ввод жилья, построенного населением, тыс м2
# 9-Объем жилищного строительства,  м2/чел
# 10-Отклонение от среднего по округу объема жилищного строительства, %
# 11-ОПЖ, 2018 г., лет
# 12-ОПЖ, 2019 г., лет
# 13-ОПЖ, 2020 г., лет
# 14-Изменение ОПЖ 2020/2019
# 15-Отклонение от среднего по округу изменения ОПЖ, лет
# 16-Прирост населения, 2018, на тыс
# 17-Прирост населения, 2019, на тыс
# 18-Прирост населения, 2020, на тыс
# 19-Изменение прироста населения, 2020/2019, %
# 20-Отклонение от среднего по округу изменения ОПЖ, лет.1
# 21-Индекс пр-сти труда 2018/2017 , %
# 22-Индекс пр-сти труда 2019/2018, %
# 23-Индекс пр-сти труда 2020 / 2019, %
# 24-Индекс пр-сти труда 2020 / 2017, %
# 25-Увеличение темпа прироста пр-сти труда  (2020/2019), %
# 26-Отклонение от среднего по округу изменения темпа пр-та пр-сти, %
# 27-Кол-во высокопр-ных мест труда 2019, тыс
# 28-Кол-во высокопр-ных мест труда 2020, тыс
# 29-Относительное кол-во высокопр-ных мест труда 2020, 1/чел
# 30-Рост высокопр-ных мест труда 2020/2019, %
# 31-Отклонение от среднего по округу роста высокопр-ных мест труда, %
# 32-Уровень бедности 2018, %
# 33-Уровень бедности 2019, %
# 34-Уровень бедности 2020, %
# 35-Уровень бедности 2020/2018, %
# 36-Уровень бедности 2020/2019, %
# 37-Отклонение изменения уровня бедности, 2020/2019, %

# %%
rel_col = [1, 2, 3, 4, 5, 9, 10, 14, 15, 19, 20, 22, 23, 25, 26, 29, 30, 33, 34, 35, 36]

# %%
rel_col_s = [3,4,14,15,18,19,20,23,25,29,30,35,36]

# %%
df_ss = df.iloc[:, rel_col_s]

# %%
df_ss.head(3)
# Out:
#                       Средняя зарплата 2020/2019, %  \
# Белгородская область                          104.5
# Брянская область                              102.2
# Владимирская область                          102.4
#
#                       Отклонение от увеличения средней зарплаты округу, %  \
# Белгородская область                                           2.705556
# Брянская область                                               0.405556
# Владимирская область                                           0.605556
#
#                       Изменение ОПЖ 2020/2019  \
# Белгородская область                    -1.81
# Брянская область                        -1.71
# Владимирская область                    -1.87
#
#                       Отклонение от среднего по округу изменения ОПЖ, лет  \
# Белгородская область                                           0.088333
# Брянская область                                               0.188333
# Владимирская область                                           0.028333
#
#                       Прирост населения, 2020, на тыс  \
# Белгородская область                             -7.6
# Брянская область                                 -9.0
# Владимирская область                            -10.8
#
#                       Изменение прироста населения, 2020/2019, %  \
# Белгородская область                                        -2.8
# Брянская область                                            -2.6
# Владимирская область                                        -3.3
#
#                       Отклонение от среднего по округу изменения ОПЖ, лет.1  \
# Белгородская область                                           0.038889
# Брянская область                                               0.238889
# Владимирская область                                          -0.461111
#
#                       Индекс пр-сти труда 2020 / 2019, %  \
# Белгородская область                               103.5
# Брянская область                                   108.1
# Владимирская область                               120.7
#
#                       Увеличение темпа прироста пр-сти труда  (2020/2019), %  \
# Белгородская область                                                1.4
# Брянская область                                                    2.5
# Владимирская область                                               17.0
#
#                       Относительное кол-во высокопр-ных мест труда 2020, 1/чел   \
# Белгородская область                                           0.140845
# Брянская область                                               0.083855
# Владимирская область                                           0.115239
#
#                       Рост высокопр-ных мест труда 2020/2019, %  \
# Белгородская область                                 109.707384
# Брянская область                                      99.196815
# Владимирская область                                 100.129482
#
#                       Уровень бедности 2020/2018, %  \
# Белгородская область                      96.000000
# Брянская область                         101.470588
# Владимирская область                      95.419847
#
#                       Уровень бедности 2020/2019, %
# Белгородская область                      92.307692
# Брянская область                         100.000000
# Владимирская область                      99.206349

# %%
df_short = df.iloc[:, rel_col]

# %%
df_short.head()
# Out:
#                       Средняя зарплата 2019/2017, %  \
# Белгородская область                       110.0040
# Брянская область                           109.2470
# Владимирская область                       112.2079
# Воронежская область                        111.5262
# Ивановская область                         108.3320
#
#                       Средняя зарплата 2020/2017, %  \
# Белгородская область                          116.1
# Брянская область                              113.7
# Владимирская область                          116.5
# Воронежская область                           114.4
# Ивановская область                            108.9
#
#                       Средняя зарплата 2020/2019, %  \
# Белгородская область                          104.5
# Брянская область                              102.2
# Владимирская область                          102.4
# Воронежская область                           101.8
# Ивановская область                            100.6
#
#                       Отклонение от увеличения средней зарплаты округу, %  \
# Белгородская область                                           2.705556
# Брянская область                                               0.405556
# Владимирская область                                           0.605556
# Воронежская область                                            0.005556
# Ивановская область                                            -1.194444
#
#                       Темп роста денежного дохода населения в 2020  \
# Белгородская область                                          98.4
# Брянская область                                              95.8
# Владимирская область                                          98.1
# Воронежская область                                           94.6
# Ивановская область                                            96.6
#
#                       Объем жилищного строительства,  м2/чел  \
# Белгородская область                                0.745235
# Брянская область                                    0.360790
# Владимирская область                                0.541093
# Воронежская область                                 0.748523
# Ивановская область                                  0.337578
#
#                       Отклонение от среднего по округу объема жилищного строительства, %  \
# Белгородская область                                           0.129463
# Брянская область                                              -0.254982
# Владимирская область                                          -0.074679
# Воронежская область                                            0.132751
# Ивановская область                                            -0.278194
#
#                       Изменение ОПЖ 2020/2019  \
# Белгородская область                    -1.81
# Брянская область                        -1.71
# Владимирская область                    -1.87
# Воронежская область                     -1.73
# Ивановская область                      -1.14
#
#                       Отклонение от среднего по округу изменения ОПЖ, лет  \
# Белгородская область                                           0.088333
# Брянская область                                               0.188333
# Владимирская область                                           0.028333
# Воронежская область                                            0.168333
# Ивановская область                                             0.758333
#
#                       Изменение прироста населения, 2020/2019, %  ...  \
# Белгородская область                                        -2.8  ...
# Брянская область                                            -2.6  ...
# Владимирская область                                        -3.3  ...
# Воронежская область                                         -2.6  ...
# Ивановская область                                          -2.2  ...
#
#                       Индекс пр-сти труда 2019/2018, %  \
# Белгородская область                        107.702922
# Брянская область                            110.300000
# Владимирская область                        108.300000
# Воронежская область                         105.100000
# Ивановская область                          107.000000
#
#                       Индекс пр-сти труда 2020 / 2019, %  \
# Белгородская область                               103.5
# Брянская область                                   108.1
# Владимирская область                               120.7
# Воронежская область                                102.5
# Ивановская область                                 109.2
#
#                       Увеличение темпа прироста пр-сти труда  (2020/2019), %  \
# Белгородская область                                                1.4
# Брянская область                                                    2.5
# Владимирская область                                               17.0
# Воронежская область                                                 3.2
# Ивановская область                                                  7.5
#
#                       Отклонение от среднего по округу изменения темпа пр-та пр-сти, %  \
# Белгородская область                                          -1.144444
# Брянская область                                              -0.044444
# Владимирская область                                          14.455556
# Воронежская область                                            0.655556
# Ивановская область                                             4.955556
#
#                       Относительное кол-во высокопр-ных мест труда 2020, 1/чел   \
# Белгородская область                                           0.140845
# Брянская область                                               0.083855
# Владимирская область                                           0.115239
# Воронежская область                                            0.119341
# Ивановская область                                             0.060874
#
#                       Рост высокопр-ных мест труда 2020/2019, %  \
# Белгородская область                                 109.707384
# Брянская область                                      99.196815
# Владимирская область                                 100.129482
# Воронежская область                                  110.053276
# Ивановская область                                   103.827544
#
#                       Уровень бедности 2019, %  Уровень бедности 2020, %  \
# Белгородская область                       7.8                       7.2
# Брянская область                          13.8                      13.8
# Владимирская область                      12.6                      12.5
# Воронежская область                        8.9                       8.5
# Ивановская область                        14.2                      13.7
#
#                       Уровень бедности 2020/2018, %  \
# Белгородская область                      96.000000
# Брянская область                         101.470588
# Владимирская область                      95.419847
# Воронежская область                       95.505618
# Ивановская область                        93.197279
#
#                       Уровень бедности 2020/2019, %
# Белгородская область                      92.307692
# Брянская область                         100.000000
# Владимирская область                      99.206349
# Воронежская область                       95.505618
# Ивановская область                        96.478873
#
# [5 rows x 21 columns]

# %%
matrix = (df.corr(method='spearman')<0.3) & (df.corr(method='spearman')>-0.2)

plt.figure(figsize=(20, 20))

sns.heatmap(df.corr(method='spearman'), annot=True,
            fmt='.1f', center=0, cmap='coolwarm', mask=matrix)
plt.show()

# %% [markdown]
# Исходя из матрицы корреляции признаков видно, что положительно скоррелированы признаки, связанные с объемом строительства и количеством жителей, кол-вом жителей и относительным количеством выскопр-ных мест труда, средней зарплаты и уровнем бедности, объемом строительства и кол-вом выскопр-ных мест труда,  приростом населения и уровня бедности.
#
# Отрицательно скоррелированы признаки, связанные с количеством жителей и уровнем бедности, кол-вом выскопр-ных мест труда и уровнем бедности, кол-вом выскопр-ных мест труда и уровнем бедности

# %%
matrix = (df_short.corr(method='spearman')<0.3) & (df_short.corr(method='spearman')>-0.2)

plt.figure(figsize=(20, 20))

sns.heatmap(df_short.corr(method='spearman'), annot=True,
            fmt='.1f', vmin=-0.3, center=0, cmap='coolwarm', mask=matrix)
plt.show()

# %%
df.drop(columns=df.columns[0], inplace=True)

# %%
df.dropna(inplace=True)

# %%
X_scaled = StandardScaler().fit_transform(df)

pca = PCA().fit(X_scaled)

plt.figure(figsize=(12, 5))
x = np.arange(1, len(pca.explained_variance_ratio_)+1)
plt.plot(x, np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--', color='b')
plt.axhline(y=0.9, color='r', linestyle='-')
plt.text(0.6, 0.85, '90% cut-off threshold', color = 'red', fontsize=12)
plt.grid(axis='x')

plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
pca = PCA(n_components=3, random_state=352)
X_pca = pca.fit_transform(X_scaled)

fig = px.scatter_3d(
    X_pca, x=0, y=1, z=2,
    labels={'color': 'species'}
)
fig.update_traces(marker_size=2)
fig.show()
# Out:
# <div>                            <div id="5d86956c-d200-4cc8-8e27-7eaa85c538f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d86956c-d200-4cc8-8e27-7eaa85c538f2")) {                    Plotly.newPlot(                        "5d86956c-d200-4cc8-8e27-7eaa85c538f2",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":2},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-1.9116476324816762,0.7028298039664298,-1.018938489888153,-2.191113978738533,0.11002352107824315,-1.7382709107393173,0.930611491626544,0.29760646510891137,-3.133997018425213,-8.843394467684284,-0.25435131093904767,-0.9559131627070712,0.5399255567806325,-0.4248981844480246,-0.36259904569458995,-1.37372990337754,-1.925239035053923,-5.770035604971132,1.634513761956467,0.11329866399986188,0.41354018906178497,1.6589847974658858,-0.13352222077435294,-3.3632292925395957,1.0421305108563166,0.031831402882797115,1.8815376984207266,-6.202569243624229,2.000505245948426,4.685449945664985,1.3775657046273064,-3.540825482853699,1.7790778602993822,-1.2144992971364792,-1.5690580141670343,0.8916373852790251,3.1386982128236034,6.5636564792268075,4.594419770332441,5.4903274883540085,1.0984117564146245,2.3070331405506503,0.44143888136411263,-2.2331726564404777,1.923472222485742,0.8895474299708013,-4.066971645984412,-0.24642694410419594,1.2342690650873451,-1.147018601183409,0.41024948912325254,-2.5396282973755713,0.004789844444069451,-0.855895596883741,-2.1064392319631757,-0.07316883034048141,-0.5102878368746785,2.6156055019007565,-2.6204921458951236,-2.833626564051825,-2.8374854759919104,-2.040521955910908,-1.7079391286129668,6.640572510819139,10.44831960491011,2.25963178417667,1.657455986124202,1.1307534845137013,0.47494324396265347,-0.1286850111726502,-0.9265785436587006,-0.31596900510830267,-0.2965261338119926],"y":[0.6584905343268402,-1.8016271587814243,-0.8766242825386299,-0.37647524376646546,-2.09729355524283,-0.7737557019694381,-3.003600496121339,-1.6993989367016333,-0.22329599963505606,3.7431795208031713,-0.8289189297765993,-1.3087068981515204,-2.5342808679082074,-2.4963125976733815,-2.8633625258514592,-1.7780577638353516,-1.7071637298062134,6.245301377559487,-1.4525461661443357,-1.682603804198674,-1.3626787898616026,-1.2717323813209327,-1.5305653492107716,-0.7988256811201644,-0.7032315997476357,-3.212989412241406,-2.3194096919877745,4.135078044978658,0.006667758257596737,3.021052088547765,-1.78168125108948,0.8814656743316991,0.42016160779691886,1.0155853315314336,0.13980058312978091,0.5551564014956588,7.187345432369793,7.952642610348987,3.747870238692683,1.7160130339465656,1.261194678357226,5.85915817047576,0.19869254946569434,0.5668358756641965,-0.6081960529968279,0.2315437492920349,2.1649796706534894,-0.4187652556166383,0.5034649028443697,-1.378860835708614,-0.8819022465341108,-2.130975311522332,-0.908366507023354,0.004686498915099255,-0.6600207374379189,0.284823463880662,-1.1683092306853535,-3.476028059099745,-1.6430129275167011,3.5742285430614067,3.549024678510011,2.207627869195771,-1.6637351034959655,-0.09453500363516394,0.5518341789260993,-0.8641361911794582,-1.5994437189434716,-0.278371810573605,-1.0752840949396927,-2.57566973235302,-0.16773665810240287,-0.8395061361851903,0.5340893608730354],"z":[0.006089423237882519,-1.1672839178367393,-3.502747900815962,1.0785920515742493,-0.5976733020627211,0.6562593270834569,1.6151894735434607,-1.3069704843407397,-1.6879971516994112,4.828043479863611,-1.547862983440972,-2.5779034569193606,0.7016745086321823,-0.041534285663519244,0.9793419359192054,-1.5986209357754921,-0.009555545191120974,3.1419017970999805,-0.8609507723430158,-2.7472689889664013,0.8699481742439051,0.260718193 ...

# %%
# %time
tsne = TSNE(n_components=3, random_state=r_seed)
X_embedding_tsne = tsne.fit_transform(df_ss)

fig = px.scatter_3d(
    X_embedding_tsne, x=0, y=1, z=2,
    labels={'color': 'species'}
)
fig.update_traces(marker_size=2)
fig.show()
# Out:
# Wall time: 0 ns
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-b990a4441ae5> in <module>
#       1 get_ipython().run_line_magic('time', '')
#       2 tsne = TSNE(n_components=3, random_state=r_seed)
# ----> 3 X_embedding_tsne = tsne.fit_transform(df_ss)
#       4
#       5 fig = px.scatter_3d(
#
# C:\Anaconda\lib\site-packages\sklearn\manifold\_t_sne.py in fit_transform(self, X, y)
#     930             Embedding of the training data in low-dimensional space.
#     931         """
# --> 932         embedding = self._fit(X)
#     933         self.embedding_ = embedding
#     934         return self.embedding_
#
# C:\Anaconda\lib\site-packages\sklearn\manifold\_t_sne.py in _fit(self, X, skip_num_points)
#     700             )
#     701         if self.method == 'barnes_hut':
# --> 702             X = self._validate_data(X, accept_sparse=['csr'],
#     703                                     ensure_min_samples=2,
#     704                                     dtype=[np.float32, np.float64])
#
# C:\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
def plot_clustering(
    data: pd.DataFrame,
    data_scale: np.array,
    embedding: np.array,
    model: sklearn.base.ClusterMixin,
    kwargs: dict,
    min_size: int = 2,
    max_size: int = 11,
    type_train: str = None,
) -> dict:
    """
    Общий метод подбора кол-ва кластеров с выодом графиков
    :param data: данные
    :param data_scale: скалированные данные
    :param embedding: эмбединги
    :param model: модель кластеризации
    :param kwargs: параметры алгоритма
    :param min_size: min кол-во кластеров
    :param max_size: max кол-во кластеров
    :param type_train: по каким данным кластеризуем
    :return: словарь с метками кластеров
    """

    calinski_harabasz = []
    silhouette_list = []
    dict_clusters = {}

    if model().__class__.__name__ == "KMeans":
        sse = []
    else:
        labels_std = []
        labels_min = []
        labels_max = []

    for clust in tqdm_notebook(range(min_size, max_size + 1)):
        fig, axes = plt.subplots(1, 2)
        fig.set_size_inches(18, 5)


        clf = model(n_clusters=clust, **kwargs)

        if type_train == "embedding":
            clf.fit(embedding)
            
        else:
            if model().__class__.__name__ == "KMeans":
                clf.fit(data_scale)
            else:
                clf.fit(data)
        
        dict_clusters[clust] = clf.labels_

        print(clust, "clusters")
        print("-" * 100)

        if clf.__class__.__name__ == "KMeans":
            sse.append(clf.inertia_)
        else:
            # добавление статистики по размерам кластеров
            _, counts = np.unique(dict_clusters[clust], return_counts=True)
            labels_std.append(np.std(counts))
            labels_min.append(np.min(counts))
            labels_max.append(np.max(counts))

        # размер кластеров
        plot_size(data, dict_clusters[clust], ax=axes[0])
        # график silhouette
        silhouette_plot(data, dict_clusters[clust], ax=axes[1])

        # calinski_harabasz
        calinski_harabasz.append(calinski_harabasz_score(data, dict_clusters[clust]))
        # silhouette
        silhouette_list.append(silhouette_score(data, dict_clusters[clust]))
        plt.show()

    if clf.__class__.__name__ == "KMeans":
        metric_picture(sse, min_size, max_size, name_metric="SSE")
    else:
        elbow_picture(
            labels_std, labels_min, labels_max, labels_max, min_size, max_size
        )

    metric_picture(
        calinski_harabasz,
        min_size,
        max_size,
        name_metric="Calinski harabasz",
        optimal=False,
    )
    metric_picture(
        silhouette_list, min_size, max_size, name_metric="Silhouette", optimal=False
    )

    return dict_clusters

# %%
params_cluster = {
    'KMeans': {
        'random_state': 251,
    },
    'SpectralClustering': {
        'random_state': r_seed,
        'affinity': 'nearest_neighbors',
        'n_neighbors': 5,
        'n_jobs': -1
    },
    'AgglomerativeClustering': {
    }
}

# %%
dict_clusters_km = plot_clustering(data=df,
                                   data_scale=X_scaled,
                                   embedding=X_pca,
                                   kwargs=params_cluster['KMeans'],
                                   model=KMeans,
                                   type_train='embedding')
# Out:
# <ipython-input-45-f535502f0ad8>:35: TqdmDeprecationWarning:
#
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2 clusters
# ----------------------------------------------------------------------------------------------------
# 3 clusters
# ----------------------------------------------------------------------------------------------------
# 4 clusters
# ----------------------------------------------------------------------------------------------------
# 5 clusters
# ----------------------------------------------------------------------------------------------------
# 6 clusters
# ----------------------------------------------------------------------------------------------------
# 7 clusters
# ----------------------------------------------------------------------------------------------------
# 8 clusters
# ----------------------------------------------------------------------------------------------------
# 9 clusters
# ----------------------------------------------------------------------------------------------------
# 10 clusters
# ----------------------------------------------------------------------------------------------------
# 11 clusters
# ----------------------------------------------------------------------------------------------------

# %%
plotting_kde_num(df, dict_clusters_km[6], df_ss.columns)
plotting_num(df, dict_clusters_km[6], df_ss.columns)

# %%
fig = px.scatter_3d(
    X_pca, x=0, y=1, z=2,
    labels={'color': 'species'},
    color=dict_clusters_km[7]
)
fig.update_traces(marker_size=2)
fig.show()
# Out:
# <div>                            <div id="ca5a63a2-68ee-4b26-b8f9-f23d5b884225" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca5a63a2-68ee-4b26-b8f9-f23d5b884225")) {                    Plotly.newPlot(                        "ca5a63a2-68ee-4b26-b8f9-f23d5b884225",                        [{"hovertemplate":"0=%{x}<br>1=%{y}<br>2=%{z}<br>species=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0,5,5,0,2,0,2,5,0,3,5,5,2,2,2,5,0,3,2,5,2,2,2,0,5,2,2,3,2,1,2,0,5,5,0,2,1,1,1,4,5,1,2,0,2,5,6,2,5,0,2,0,5,5,0,5,2,2,0,6,6,6,0,4,4,2,2,2,5,2,0,5,5],"coloraxis":"coloraxis","symbol":"circle","size":2},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-1.9116476324816762,0.7028298039664298,-1.018938489888153,-2.191113978738533,0.11002352107824315,-1.7382709107393173,0.930611491626544,0.29760646510891137,-3.133997018425213,-8.843394467684284,-0.25435131093904767,-0.9559131627070712,0.5399255567806325,-0.4248981844480246,-0.36259904569458995,-1.37372990337754,-1.925239035053923,-5.770035604971132,1.634513761956467,0.11329866399986188,0.41354018906178497,1.6589847974658858,-0.13352222077435294,-3.3632292925395957,1.0421305108563166,0.031831402882797115,1.8815376984207266,-6.202569243624229,2.000505245948426,4.685449945664985,1.3775657046273064,-3.540825482853699,1.7790778602993822,-1.2144992971364792,-1.5690580141670343,0.8916373852790251,3.1386982128236034,6.5636564792268075,4.594419770332441,5.4903274883540085,1.0984117564146245,2.3070331405506503,0.44143888136411263,-2.2331726564404777,1.923472222485742,0.8895474299708013,-4.066971645984412,-0.24642694410419594,1.2342690650873451,-1.147018601183409,0.41024948912325254,-2.5396282973755713,0.004789844444069451,-0.855895596883741,-2.1064392319631757,-0.07316883034048141,-0.5102878368746785,2.6156055019007565,-2.6204921458951236,-2.833626564051825,-2.8374854759919104,-2.040521955910908,-1.7079391286129668,6.640572510819139,10.44831960491011,2.25963178417667,1.657455986124202,1.1307534845137013,0.47494324396265347,-0.1286850111726502,-0.9265785436587006,-0.31596900510830267,-0.2965261338119926],"y":[0.6584905343268402,-1.8016271587814243,-0.8766242825386299,-0.37647524376646546,-2.09729355524283,-0.7737557019694381,-3.003600496121339,-1.6993989367016333,-0.22329599963505606,3.7431795208031713,-0.8289189297765993,-1.3087068981515204,-2.5342808679082074,-2.4963125976733815,-2.8633625258514592,-1.7780577638353516,-1.7071637298062134,6.245301377559487,-1.4525461661443357,-1.682603804198674,-1.3626787898616026,-1.2717323813209327,-1.5305653492107716,-0.7988256811201644,-0.7032315997476357,-3.212989412241406,-2.3194096919877745,4.135078044978658,0.006667758257596737,3.021052088547765,-1.78168125108948,0.8814656743316991,0.42016160779691886,1.0155853315314336,0.13980058312978091,0.5551564014956588,7.187345432369793,7.952642610348987,3.747870238692683,1.7160130339465656,1.261194678357226,5.85915817047576,0.19869254946569434,0.5668358756641965,-0.6081960529968279,0.2315437492920349,2.1649796706534894,-0.4187652556166383,0.5034649028443697,-1.378860835708614,-0.8819022465341108,-2.130975311522332,-0.908366507023354,0.004686498915099255,-0.6600207374379189,0.284823463880662,-1.1683092306853535,-3.476028059099745,-1.6430129275167011,3.5742285430614067,3.549024678510011,2.207627869195771,-1.6637351034959655,-0.09453500363516394,0.5518341789260993,-0.8641361911794582,-1.5994437189434716,-0.278371810573605,-1.0752840949396927,-2.57566973235302,-0.16773665810240287,-0.8395061361851903,0.5340893608730354],"z":[0.006089423237882519,-1.1672839178367393,-3.502747900815962,1.0785920515742493,-0.5976733020627211,0.6562593270834569,1.6151894735434607,-1.3069704843407397,-1.6879971516994112,4.828043479863611,-1.547862983440972,-2.5779034569193606,0. ...

# %%
sns.scatterplot(X_pca[:,0], X_pca[:,1], c=dict_clusters_km[7])

# %%
X_scaled = StandardScaler().fit_transform(df)

pca = PCA().fit(X_scaled)

plt.figure(figsize=(12, 5))
x = np.arange(1, len(pca.explained_variance_ratio_)+1)
plt.plot(x, np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--', color='b')
plt.axhline(y=0.9, color='r', linestyle='-')
plt.text(0.6, 0.85, '90% cut-off threshold', color = 'red', fontsize=12)
plt.grid(axis='x')

plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
pca = PCA(n_components=0.9).fit(X_scaled)

components = pca.fit_transform(X_scaled)
total_var = pca.explained_variance_ratio_.sum() * 100
n_components = len(pca.explained_variance_ratio_)

labels = {str(i): f"PC {i+1}" for i in range(n_components)}
labels['color'] = 'Median Price'
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    dimensions=range(n_components),
    labels=labels,
    title=f'Total Explained Variance: {total_var:.2f}%',
)
fig.update_traces(marker_size=1, diagonal_visible=False)

fig.update_layout(
    font=dict(size=10, color='black'),
    autosize=False,
    width=1000,
    height=800,
)
fig.show()

# %%
pca = PCA(n_components=0.9, random_state=r_seed)
X_pca = pca.fit_transform(X_scaled)

fig = px.scatter_3d(
    X_pca, x=0, y=1, z=2,
    labels={'color': 'species'}
)
fig.update_traces(marker_size=2)
fig.show()

# %%
dict_clusters_km = plot_clustering(data=df,
                                   data_scale=X_scaled,
                                   embedding=X_pca,
                                   kwargs=params_cluster['KMeans'],
                                   model=KMeans,
                                   type_train='embedding')

# %%
plotting_kde_num(df, dict_clusters_km[4], df.columns)
plotting_num(df, dict_clusters_km[4], df.columns)

# %%
dict_clusters_spec = plot_clustering(
    data=df,
    data_scale=None,
    embedding=X_pca,
    kwargs=params_cluster['SpectralClustering'],
    model=SpectralClustering,
    type_train='embedding')

# %%
plotting_kde_num(df_ss, dict_clusters_spec[6], df_ss.columns)
plotting_num(df_ss, dict_clusters_spec[6], df_ss.columns)

# %%
dict_clusters_ag = plot_clustering(
    data=df_ss,
    data_scale=None,
    embedding=X_pca,
    kwargs=params_cluster['AgglomerativeClustering'],
    model=AgglomerativeClustering,
    type_train='embedding')

# %%
plotting_kde_num(df_ss, dict_clusters_ag[2], df_ss.columns)
plotting_num(df_ss, dict_clusters_ag[2], df_ss.columns)

# %%
matrix = (df_ss.corr(method='spearman')<0.3) & (df_ss.corr(method='spearman')>-0.2)

plt.figure(figsize=(20, 20))

sns.heatmap(df_ss.corr(method='spearman'), annot=True,
            fmt='.1f', center=0, cmap='coolwarm', mask=matrix)
plt.show()

# %%
clusters = .labels_
